# %%
# Dependencies and Setup
import hvplot.pandas
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path
import requests as req
import time
import scipy.stats as st
from datetime import datetime
from scipy.stats import linregress
# Import the OpenWeatherMap API key
from api_key import weather_api_key
# Import geoapify API key
from api_key import geoapify_key
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d4d4116e-2d52-41a4-afd6-6177696c3da7" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2185fa68-f4fd-4d29-8568-1fba6a5f7265":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"e540a308222b482ba1ec490e6e7fd3e5","client_comm_id":"e7636ef059164449a13afc79eed9bd3b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"2185fa68-f4fd-4d29-8568-1fba6a5f7265","roots":{"p1002":"d4d4116e-2d52-41a4-afd6-6177696c3da7"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#Calling openbrewerydb website to obtain all breweries worlwide.
beer_info_df = pd.DataFrame({'id':[],'name':[],'brewery_type':[],'address_1':[],'address_2':[],'address_3':[],
                             'city':[],'state_province':[],'postal_code':[],'country':[],'longitude':[],'latitude':[],
                             'phone':[],'website_url':[],'state':[],'street':[]})
try:
    page_count = int(8000 / 200)
    #page_count = 5 #testing
    for i in range(page_count):
        path = f"https://api.openbrewerydb.org/v1/breweries?per_page=200&page={str(i)}"
        print(path)
        beer_info = req.get(path).json()
        beer_info = pd.DataFrame(beer_info)
        beer_info_df = pd.concat([beer_info_df, beer_info], ignore_index=True)
except:
    
    print(f'Stopped at {i} pages')
beer_info_df
# Out:
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=0
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=1
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=2
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=3
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=4
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=5
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=6
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=7
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=8
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=9
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=10
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=11
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=12
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=13
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=14
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=15
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=16
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=17
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=18
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=19
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=20
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=21
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=22
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=23
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=24
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=25
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=26
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=27
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=28
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=29
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=30
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=31
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=32
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=33
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=34
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=35
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=36
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=37
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=38
# https://api.openbrewerydb.org/v1/breweries?per_page=200&page=39
#                                         id  \
# 0     5128df48-79fc-4f0f-8b52-d06be54d0cec
# 1     9c5a66c8-cc13-416f-a5d9-0a769c87d318
# 2     34e8c68b-6146-453f-a4b9-1f6cd99a5ada
# 3     ef970757-fe42-416f-931d-722451f1f59c
# 4     6d14b220-8926-4521-8d19-b98a2d6ec3db
# ...                                    ...
# 7995  caa654e3-bfa9-4019-8e83-2aca7a423720
# 7996  392b4940-7333-4a2e-9e64-3b12e0290354
# 7997  60fad081-4a4e-4415-95d8-b478cb0ce9c1
# 7998  b3be1ab8-d34b-465c-9704-b50364cfd061
# 7999  9fb445cd-bd7c-4b97-a249-ef17e9856cc0
#
#                                                 name brewery_type  \
# 0                                   (405) Brewing Co        micro
# 1                                   (512) Brewing Co        micro
# 2                            1 of Us Brewing Company        micro
# 3                               10 Barrel Brewing Co        large
# 4                               10 Barrel Brewing Co        large
# ...                                              ...          ...
# 7995                              Victory Brewing Co      brewpub
# 7996                              Victory Brewing Co     regional
# 7997  Vierling Restaurant & Marquette Harbor Brewery      brewpub
# 7998                            Viewpoint Brewing Co      brewpub
# 7999                                  Viking Brewpub      brewpub
#
#                        address_1 address_2 address_3            city  \
# 0                 1716 Topeka St      None      None          Norman
# 1          407 Radam Ln Ste F200      None      None          Austin
# 2            8100 Washington Ave      None      None  Mount Pleasant
# 3                      1501 E St      None      None       San Diego
# 4                  62970 18th St      None      None            Bend
# ...                          ...       ...       ...             ...
# 7995      650 W Cypress St Ste 1      None      None  Kennett Square
# 7996        3127 Lower Valley Rd      None      None      Parkesburg
# 7997              119 S Front St      None      None       Marquette
# 7998  2201 San Dieguito Dr Ste F      None      None         del Mar
# 7999               211 E Main St      None      None       Stoughton
#
#      state_province postal_code        country           longitude  \
# 0          Oklahoma  73069-8224  United States        -97.46818222
# 1             Texas  78745-1197  United States                None
# 2         Wisconsin  53406-3920  United States  -87.88336350209435
# 3        California  92101-6618  United States         -117.129593
# 4            Oregon  97701-9847  United States         -121.281706
# ...             ...         ...            ...                 ...
# 7995   Pennsylvania  19348-3059  United States                None
# 7996   Pennsylvania  19365-9617  United States                None
# 7997       Michigan  49855-4642  United States         -87.3928955
# 7998     California  92014-2257  United States        -117.2618232
# 7999      Wisconsin  53589-1700  United States         -89.2188242
#
#                latitude       phone                      website_url  \
# 0           35.25738891  4058160490        http://www.405brewing.com
# 1                  None  5129211545        http://www.512brewing.com
# 2     42.72010826899558  2624847553     https://www.1ofusbrewing.com
# 3             32.714813  6195782311              http://10barrel.com
# 4           44.08683531  5415851007          http://www.10barrel.com
# ...                 ...         ...                              ...
# 7995               None  4847301870       http://www.victorybeer.com
# 7996               None  6108730881       http://www.victorybeer.com
# 7997         46.5425586  9062283533       http://www.thevierling.com
# 7998          32.970049  8583569346  http://www.viewpointbrewing.com
# 7999         42.9166357  6087195041                             None
#
#              state                      street
# 0         Oklahoma              1716 Topeka St
# 1            Texas       407 Radam Ln Ste F200
# 2        Wisconsin         8100 Washington Ave
# 3       California                   1501 E St
# 4           Oregon               62970 18th St
# ...            ...                         ...
# 7995  Pennsylvania      650 W Cypress St Ste 1
# 7996  Pennsylvania        3127 Lower Valley Rd
# 7997      Michigan              119 S Front St
# 7998    California  2201 San Dieguito Dr Ste F
# 7999     Wisconsin               211 E Main St
#
# [8000 rows x 16 columns]

# %%
#copying DF to new DF
Brewery_df = beer_info_df.copy()

# %%
#Dropped any rows that had none in the longitude field.
Brewery_df.dropna(subset=['longitude'], inplace=True)

# %%
Brewery_df
# Out:
#                                         id  \
# 0     5128df48-79fc-4f0f-8b52-d06be54d0cec
# 2     34e8c68b-6146-453f-a4b9-1f6cd99a5ada
# 3     ef970757-fe42-416f-931d-722451f1f59c
# 4     6d14b220-8926-4521-8d19-b98a2d6ec3db
# 5     e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2
# ...                                    ...
# 7992  4c321585-4c57-400b-9a56-fb95767b8cee
# 7993  ccae7ca3-7457-44cf-8138-f6f5d8959b8c
# 7997  60fad081-4a4e-4415-95d8-b478cb0ce9c1
# 7998  b3be1ab8-d34b-465c-9704-b50364cfd061
# 7999  9fb445cd-bd7c-4b97-a249-ef17e9856cc0
#
#                                                 name brewery_type  \
# 0                                   (405) Brewing Co        micro
# 2                            1 of Us Brewing Company        micro
# 3                               10 Barrel Brewing Co        large
# 4                               10 Barrel Brewing Co        large
# 5                               10 Barrel Brewing Co        large
# ...                                              ...          ...
# 7992                          Vicious Fishes Brewery        micro
# 7993                         Victor 23 Craft Brewery      brewpub
# 7997  Vierling Restaurant & Marquette Harbor Brewery      brewpub
# 7998                            Viewpoint Brewing Co      brewpub
# 7999                                  Viking Brewpub      brewpub
#
#                         address_1 address_2 address_3            city  \
# 0                  1716 Topeka St      None      None          Norman
# 2             8100 Washington Ave      None      None  Mount Pleasant
# 3                       1501 E St      None      None       San Diego
# 4                   62970 18th St      None      None            Bend
# 5     1135 NW Galveston Ave Ste B      None      None            Bend
# ...                           ...       ...       ...             ...
# 7992                  219 Fish Dr      None      None          Angier
# 7993           2905 St Johns Blvd      None      None       Vancouver
# 7997               119 S Front St      None      None       Marquette
# 7998   2201 San Dieguito Dr Ste F      None      None         del Mar
# 7999                211 E Main St      None      None       Stoughton
#
#       state_province postal_code        country           longitude  \
# 0           Oklahoma  73069-8224  United States        -97.46818222
# 2          Wisconsin  53406-3920  United States  -87.88336350209435
# 3         California  92101-6618  United States         -117.129593
# 4             Oregon  97701-9847  United States         -121.281706
# 5             Oregon  97703-2465  United States        -121.3288021
# ...              ...         ...            ...                 ...
# 7992  North Carolina  27501-6077  United States          -78.749408
# 7993      Washington  98661-3718  United States        -122.6464236
# 7997        Michigan  49855-4642  United States         -87.3928955
# 7998      California  92014-2257  United States        -117.2618232
# 7999       Wisconsin  53589-1700  United States         -89.2188242
#
#                latitude       phone                      website_url  \
# 0           35.25738891  4058160490        http://www.405brewing.com
# 2     42.72010826899558  2624847553     https://www.1ofusbrewing.com
# 3             32.714813  6195782311              http://10barrel.com
# 4           44.08683531  5415851007          http://www.10barrel.com
# 5            44.0575649  5415851007                             None
# ...                 ...         ...                              ...
# 7992          35.507541  9196393369     http://www.viciousfishes.com
# 7993         45.6426306  3609845413          http://www.Victor23.com
# 7997         46.5425586  9062283533       http://www.thevierling.com
# 7998          32.970049  8583569346  http://www.viewpointbrewing.com
# 7999         42.9166357  6087195041                             None
#
#                state                       street
# 0           Oklahoma               1716 Topeka St
# 2          Wisconsin          8100 Washington Ave
# 3         California                    1501 E St
# 4             Oregon                62970 18th St
# 5             Oregon  1135 NW Galveston Ave Ste B
# ...              ...                          ...
# 7992  North Carolina                  219 Fish Dr
# 7993      Washington           2905 St Johns Blvd
# 7997        Michigan               119 S Front St
# 7998      California   2201 San Dieguito Dr Ste F
# 7999       Wisconsin                211 E Main St
#
# [5736 rows x 16 columns]

# %%
#creating DataFrame for US only Breweries
Brewery_us=[]
for i,row in Brewery_df.iterrows():
    if row['country'] == "United States":
        Brewery_us.append(row)
Brewery_us_df = pd.DataFrame(Brewery_us)

# %%
Brewery_us_df.to_csv("../Data/Project_Data/Brewery_project_one.csv")

# %%
Brewery_us_df
# Out:
#                                         id  \
# 0     5128df48-79fc-4f0f-8b52-d06be54d0cec
# 2     34e8c68b-6146-453f-a4b9-1f6cd99a5ada
# 3     ef970757-fe42-416f-931d-722451f1f59c
# 4     6d14b220-8926-4521-8d19-b98a2d6ec3db
# 5     e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2
# ...                                    ...
# 7992  4c321585-4c57-400b-9a56-fb95767b8cee
# 7993  ccae7ca3-7457-44cf-8138-f6f5d8959b8c
# 7997  60fad081-4a4e-4415-95d8-b478cb0ce9c1
# 7998  b3be1ab8-d34b-465c-9704-b50364cfd061
# 7999  9fb445cd-bd7c-4b97-a249-ef17e9856cc0
#
#                                                 name brewery_type  \
# 0                                   (405) Brewing Co        micro
# 2                            1 of Us Brewing Company        micro
# 3                               10 Barrel Brewing Co        large
# 4                               10 Barrel Brewing Co        large
# 5                               10 Barrel Brewing Co        large
# ...                                              ...          ...
# 7992                          Vicious Fishes Brewery        micro
# 7993                         Victor 23 Craft Brewery      brewpub
# 7997  Vierling Restaurant & Marquette Harbor Brewery      brewpub
# 7998                            Viewpoint Brewing Co      brewpub
# 7999                                  Viking Brewpub      brewpub
#
#                         address_1 address_2 address_3            city  \
# 0                  1716 Topeka St      None      None          Norman
# 2             8100 Washington Ave      None      None  Mount Pleasant
# 3                       1501 E St      None      None       San Diego
# 4                   62970 18th St      None      None            Bend
# 5     1135 NW Galveston Ave Ste B      None      None            Bend
# ...                           ...       ...       ...             ...
# 7992                  219 Fish Dr      None      None          Angier
# 7993           2905 St Johns Blvd      None      None       Vancouver
# 7997               119 S Front St      None      None       Marquette
# 7998   2201 San Dieguito Dr Ste F      None      None         del Mar
# 7999                211 E Main St      None      None       Stoughton
#
#       state_province postal_code        country           longitude  \
# 0           Oklahoma  73069-8224  United States        -97.46818222
# 2          Wisconsin  53406-3920  United States  -87.88336350209435
# 3         California  92101-6618  United States         -117.129593
# 4             Oregon  97701-9847  United States         -121.281706
# 5             Oregon  97703-2465  United States        -121.3288021
# ...              ...         ...            ...                 ...
# 7992  North Carolina  27501-6077  United States          -78.749408
# 7993      Washington  98661-3718  United States        -122.6464236
# 7997        Michigan  49855-4642  United States         -87.3928955
# 7998      California  92014-2257  United States        -117.2618232
# 7999       Wisconsin  53589-1700  United States         -89.2188242
#
#                latitude       phone                      website_url  \
# 0           35.25738891  4058160490        http://www.405brewing.com
# 2     42.72010826899558  2624847553     https://www.1ofusbrewing.com
# 3             32.714813  6195782311              http://10barrel.com
# 4           44.08683531  5415851007          http://www.10barrel.com
# 5            44.0575649  5415851007                             None
# ...                 ...         ...                              ...
# 7992          35.507541  9196393369     http://www.viciousfishes.com
# 7993         45.6426306  3609845413          http://www.Victor23.com
# 7997         46.5425586  9062283533       http://www.thevierling.com
# 7998          32.970049  8583569346  http://www.viewpointbrewing.com
# 7999         42.9166357  6087195041                             None
#
#                state                       street
# 0           Oklahoma               1716 Topeka St
# 2          Wisconsin          8100 Washington Ave
# 3         California                    1501 E St
# 4             Oregon                62970 18th St
# 5             Oregon  1135 NW Galveston Ave Ste B
# ...              ...                          ...
# 7992  North Carolina                  219 Fish Dr
# 7993      Washington           2905 St Johns Blvd
# 7997        Michigan               119 S Front St
# 7998      California   2201 San Dieguito Dr Ste F
# 7999       Wisconsin                211 E Main St
#
# [5524 rows x 16 columns]

# %%
# Filter
map_points_df = beer_info_df.loc[beer_info_df['country'] == 'United States']
map_points_df = map_points_df.loc[beer_info_df['brewery_type'] == 'brewpub'].sample(1000)
# Grab the columns used for the map
map_points_df = map_points_df[['longitude','latitude','name','brewery_type','city', 'state', 'website_url']].copy()
# Drop useless data
map_points_df = map_points_df.mask(map_points_df.eq('None')).dropna()
# Convert Lat Lon to numbers
map_points_df['longitude'] = pd.to_numeric(map_points_df['longitude'])
map_points_df['latitude'] = pd.to_numeric(map_points_df['latitude'])
# Set Map Plot
brewery_map_plot = map_points_df.hvplot.points(
    "longitude",
    "latitude",
    hover_cols = ['name', 'brewery_type', 'state', 'website_url'],
    geo = True,
    tiles = "OSM",
    frame_width = 1000,
    frame_height = 800,
    size = 5,
    scale = 2.0,
    color = "city",
    title = "Locations of Brewery/Pub only (1000 Samples)",
    fill_alpha = .5
)
# Display Map Plot
brewery_map_plot
# Out:
# C:\Users\scorp\anaconda3\envs\dev\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [longitude,latitude]   (city,name,brewery_type,state,website_url)

# %%
# Filter
map_points_df = beer_info_df.loc[beer_info_df['country'] == 'United States']
map_points_df = map_points_df.loc[beer_info_df['brewery_type'] == 'micro'].sample(1000)
# Grab the columns used for the map
map_points_df = map_points_df[['longitude','latitude','name','brewery_type','city', 'state', 'website_url']].copy()
# Drop useless data
map_points_df = map_points_df.mask(map_points_df.eq('None')).dropna()
# Convert Lat Lon to numbers
map_points_df['longitude'] = pd.to_numeric(map_points_df['longitude'])
map_points_df['latitude'] = pd.to_numeric(map_points_df['latitude'])
# Set Map Plot
brewery_map_plot2 = map_points_df.hvplot.points(
    "longitude",
    "latitude",
    hover_cols = ['name', 'brewery_type', 'state', 'website_url'],
    geo = True,
    tiles = "OSM",
    frame_width = 1000,
    frame_height = 800,
    size = 5,
    scale = 2.0,
    color = "city",
    title = "Locations of micro only (1000 Samples)",
    fill_alpha = .5
)
# Display Map Plot
brewery_map_plot2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [longitude,latitude]   (city,name,brewery_type,state,website_url)

# %%
brewery_type_df = Brewery_us_df.groupby("brewery_type")["state"].count()
brewery_type_df
# Out:
# brewery_type
# bar              2
# brewpub       1866
# closed         139
# contract       118
# large           64
# location         1
# micro         3004
# nano             8
# planning       107
# proprietor      48
# regional       166
# taproom          1
# Name: state, dtype: int64

# %%
#Grouping by states to obtain count per states
state_brewery = Brewery_us_df.groupby("state")["id"].count()
state_brewery = pd.DataFrame(state_brewery)
#sorting data, dropping incorrectly spelled Missouri row
state_brewery_sort = state_brewery.sort_values("id", ascending=False)
state_brewery_sort.drop("MIssouri",inplace=True)
state_brewery_sort
# Out:
#                        id
# state
# California            904
# Washington            423
# Oregon                277
# Michigan              270
# Colorado              247
# New York              223
# Ohio                  210
# Pennsylvania          181
# Wisconsin             176
# North Carolina        174
# Texas                 171
# Illinois              161
# Florida               161
# Missouri              130
# Virginia              127
# Minnesota             120
# Massachusetts          97
# Iowa                   92
# Indiana                85
# Arizona                74
# Tennessee              71
# Maine                  66
# Idaho                  59
# Montana                56
# New Jersey             55
# Georgia                53
# New Mexico             53
# Alaska                 53
# New Hampshire          50
# Maryland               48
# Nebraska               48
# Kentucky               46
# Connecticut            43
# South Carolina         42
# South Dakota           40
# Oklahoma               39
# Wyoming                37
# Alabama                37
# West Virginia          36
# Utah                   35
# Arkansas               30
# Rhode Island           29
# Kansas                 29
# Nevada                 28
# North Dakota           25
# Vermont                25
# Louisiana              24
# Hawaii                 21
# Delaware               16
# Mississippi            13
# District of Columbia   11
# Washington              1
#  Utah                   1

# %%
#Plot Bar chart showing each states brewery count.
state_brewery_sort.plot(kind = "bar", title = "Breweries per state", legend = False, figsize=[15,6])
plt.xlabel("States")
plt.ylabel("# of Breweries in State")
plt.tight_layout()
plt.savefig("../Outputs/Breweries per state.png")

# %%
# Read csv
income_df = Path("../Data/Project_Data/average-income-by-state-2024.csv")
avg_income_df = pd.read_csv(income_df)
avg_income_df
# Out:
#                    state  AverageIncomePerCapita2022  \
# 0                Alabama                50637.000000
# 1                 Alaska                68919.000000
# 2                Arizona                56667.000000
# 3               Arkansas                51787.000000
# 4             California                77339.000000
# 5               Colorado                74167.000000
# 6            Connecticut                84972.000000
# 7               Delaware                61387.000000
# 8   District of Columbia                96728.000000
# 9                Florida                63597.000000
# 10               Georgia                57129.000000
# 11                Hawaii                61175.000000
# 12                 Idaho                54537.000000
# 13              Illinois                68822.000000
# 14               Indiana                57930.000000
# 15                  Iowa                58905.000000
# 16                Kansas                60152.000000
# 17              Kentucky                52109.000000
# 18             Louisiana                54622.000000
# 19                 Maine                59463.000000
# 20              Maryland                70730.000000
# 21         Massachusetts                84945.000000
# 22              Michigan                56813.000000
# 23             Minnesota                68010.000000
# 24           Mississippi                46248.000000
# 25              Missouri                56551.000000
# 26               Montana                57719.000000
# 27              Nebraska                63321.000000
# 28                Nevada                61282.000000
# 29         New Hampshire                74663.000000
# 30            New Jersey                78700.000000
# 31            New Mexico                51500.000000
# 32              New York                78089.000000
# 33        North Carolina                57416.000000
# 34          North Dakota                66184.000000
# 35                  Ohio                57880.000000
# 36              Oklahoma                54998.000000
# 37                Oregon                62767.000000
# 38          Pennsylvania                65167.000000
# 39          Rhode Island                65377.000000
# 40        South Carolina                53320.000000
# 41          South Dakota                65806.000000
# 42             Tennessee                58279.000000
# 43                 Texas                61985.000000
# 44                  Utah                57925.000000
# 45               Vermont                63206.000000
# 46              Virginia                68211.000000
# 47            Washington                75698.000000
# 48         West Virginia                49169.000000
# 49             Wisconsin                61210.000000
# 50               Wyoming                71342.000000
# 51         United States                63442.254902
#
#     AverageIncomePerCapita2021
# 0                 49671.000000
# 1                 65677.000000
# 2                 55574.000000
# 3                 50588.000000
# 4                 76800.000000
# 5                 70715.000000
# 6                 82885.000000
# 7                 59846.000000
# 8                 96659.000000
# 9                 62136.000000
# 10                55846.000000
# 11                60711.000000
# 12                52276.000000
# 13                67165.000000
# 14                56435.000000
# 15                57080.000000
# 16                58857.000000
# 17                51298.000000
# 18                54181.000000
# 19                58272.000000
# 20                69710.000000
# 21                83593.000000
# 22                56569.000000
# 23                66232.000000
# 24                45887.000000
# 25                55310.000000
# 26                56848.000000
# 27                61210.000000
# 28                60167.000000
# 29                73279.000000
# 30                77009.000000
# 31                50292.000000
# 32                76753.000000
# 33                56095.000000
# 34                64276.000000
# 35                56955.000000
# 36                53808.000000
# 37                61449.000000
# 38                64042.000000
# 39                64296.000000
# 40                52441.000000
# 41                64405.000000
# 42                56616.000000
# 43                59802.000000
# 44                56000.000000
# 45                61748.000000
# 46                66190.000000
# 47                73755.000000
# 48                48418.000000
# 49                59787.000000
# 50                69584.000000
# 51                62062.705882

# %%
#merging csv file and sorted column of counted breweries per state.
income_to_Brewery_df = pd.merge(avg_income_df,state_brewery_sort, how = "left", on = ['state','state' ] )

#renaming column and dropping United states row.
income_to_Brewery_df=income_to_Brewery_df.rename(columns={'id': '# of Breweries'})
income_to_Brewery_df.dropna(subset=['# of Breweries'], inplace=True)
income_to_Brewery_df
# Out:
#                    state  AverageIncomePerCapita2022  \
# 0                Alabama                     50637.0
# 1                 Alaska                     68919.0
# 2                Arizona                     56667.0
# 3               Arkansas                     51787.0
# 4             California                     77339.0
# 5               Colorado                     74167.0
# 6            Connecticut                     84972.0
# 7               Delaware                     61387.0
# 8   District of Columbia                     96728.0
# 9                Florida                     63597.0
# 10               Georgia                     57129.0
# 11                Hawaii                     61175.0
# 12                 Idaho                     54537.0
# 13              Illinois                     68822.0
# 14               Indiana                     57930.0
# 15                  Iowa                     58905.0
# 16                Kansas                     60152.0
# 17              Kentucky                     52109.0
# 18             Louisiana                     54622.0
# 19                 Maine                     59463.0
# 20              Maryland                     70730.0
# 21         Massachusetts                     84945.0
# 22              Michigan                     56813.0
# 23             Minnesota                     68010.0
# 24           Mississippi                     46248.0
# 25              Missouri                     56551.0
# 26               Montana                     57719.0
# 27              Nebraska                     63321.0
# 28                Nevada                     61282.0
# 29         New Hampshire                     74663.0
# 30            New Jersey                     78700.0
# 31            New Mexico                     51500.0
# 32              New York                     78089.0
# 33        North Carolina                     57416.0
# 34          North Dakota                     66184.0
# 35                  Ohio                     57880.0
# 36              Oklahoma                     54998.0
# 37                Oregon                     62767.0
# 38          Pennsylvania                     65167.0
# 39          Rhode Island                     65377.0
# 40        South Carolina                     53320.0
# 41          South Dakota                     65806.0
# 42             Tennessee                     58279.0
# 43                 Texas                     61985.0
# 44                  Utah                     57925.0
# 45               Vermont                     63206.0
# 46              Virginia                     68211.0
# 47            Washington                     75698.0
# 48         West Virginia                     49169.0
# 49             Wisconsin                     61210.0
# 50               Wyoming                     71342.0
#
#     AverageIncomePerCapita2021  # of Breweries
# 0                      49671.0            37.0
# 1                      65677.0            53.0
# 2                      55574.0            74.0
# 3                      50588.0            30.0
# 4                      76800.0           904.0
# 5                      70715.0           247.0
# 6                      82885.0            43.0
# 7                      59846.0            16.0
# 8                      96659.0            11.0
# 9                      62136.0           161.0
# 10                     55846.0            53.0
# 11                     60711.0            21.0
# 12                     52276.0            59.0
# 13                     67165.0           161.0
# 14                     56435.0            85.0
# 15                     57080.0            92.0
# 16                     58857.0            29.0
# 17                     51298.0            46.0
# 18                     54181.0            24.0
# 19                     58272.0            66.0
# 20                     69710.0            48.0
# 21                     83593.0            97.0
# 22                     56569.0           270.0
# 23                     66232.0           120.0
# 24                     45887.0            13.0
# 25                     55310.0           130.0
# 26                     56848.0            56.0
# 27                     61210.0            48.0
# 28                     60167.0            28.0
# 29                     73279.0            50.0
# 30                     77009.0            55.0
# 31                     50292.0            53.0
# 32                     76753.0           223.0
# 33                     56095.0           174.0
# 34                     64276.0            25.0
# 35                     56955.0           210.0
# 36                     53808.0            39.0
# 37                     61449.0           277.0
# 38                     64042.0           181.0
# 39                     64296.0            29.0
# 40                     52441.0            42.0
# 41                     64405.0            40.0
# 42                     56616.0            71.0
# 43                     59802.0           171.0
# 44                     56000.0            35.0
# 45                     61748.0            25.0
# 46                     66190.0           127.0
# 47                     73755.0           423.0
# 48                     48418.0            36.0
# 49                     59787.0           176.0
# 50                     69584.0            37.0

# %%
avg_inc_2022 = income_to_Brewery_df['AverageIncomePerCapita2022']
brewery = income_to_Brewery_df['# of Breweries']
plt.scatter(brewery, avg_inc_2022)
plt.xlabel("# of Breweries per state")
plt.ylabel("Average Income 2022")
(slope, intercept, rvalue, pvalue, stderr) = linregress(brewery,avg_inc_2022)
regress_value = brewery * slope + intercept
line_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))
plt.plot(brewery, regress_value, "r-")
plt.annotate(line_eq, (5.8,0.8), fontsize=15, color = "red")
print(f"The rvalue is: {round(rvalue**2,2)}") 
plt.show()
# Out:
# The rvalue is: 0.07
